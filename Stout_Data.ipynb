# %% [markdown]
# # Data In Hand

# %% [markdown]
# For my data I made a CSV file using the data I found on a website that includes just wrestling data called, WrestingData.com.
# This data is to show which large WWE event has the highest arena attendance in 2024.
# I organized the data into 3 columns, "Date", "Event", and "Attendance".
# Then, I have 17 rows for the 17 events I found.
# The mean of the data is 25,786.53, the median of the data is 16,092, there is no mode in the data, and the range in the data is 72,055.

# %%
import pandas as pd

# %%
attendance = pd.read_csv(r'/Users/kenzee.stout/Data In EMAT 2025/WWE Data(Attendance).csv')
attendance.head(17)
# Out:
#           Date                                Event Attendance  Unnamed: 3
# 0     4/7/2024        WWE WrestleMania XL - Night 2     72,755         NaN
# 1     4/6/2024        WWE WrestleMania XL - Night 1     72,543         NaN
# 2     8/3/2024                  WWE SummerSlam 2024     57,791         NaN
# 3    2/24/2024         WWE Elimination Chamber 2024     52,590         NaN
# 4    1/27/2024                WWE Royal Rumble 2024     48,044         NaN
# 5     7/6/2024           WWE Money in the Bank 2024     19,885         NaN
# 6   11/30/2024   WWE Survivor Series: WarGames 2024     17,828         NaN
# 7     4/6/2024         WWE NXT Stand & Deliver 2024     16,545         NaN
# 8    10/5/2024                   WWE Bad Blood 2024     16,092         NaN
# 9   12/14/2024  WWE Saturday Night's Main Event #37     15,021         NaN
# 10   8/31/2024                   WWE Bash in Berlin     13,149         NaN
# ...
