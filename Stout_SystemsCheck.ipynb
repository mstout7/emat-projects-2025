# %% [markdown]
# # Data in Emerging Media and Technology Fall 2025
# I am very excited to learn a new skill and use my knowledge for the future.

# %% [markdown]
# ## What I Want to Learn
# This is a list of things I want to take away and learn from this course
#
# - Learn how to use _python_
# - Learn how to __manipulate__ and __analyze__ _data_
# - Learn how to use __more__ _code_ in a different setting
# - Learn how to use this __knowledge__ into my _web design_

# %% [markdown]
# ### It Don't Bite
# ![https___dev-to-uploads.s3.amazonaws.com_uploads_articles_c7cziks7c4dezyz8lkqs.webp](attachment:588eafb5-e7b5-4bde-9918-214ba8ff77f3.webp)
